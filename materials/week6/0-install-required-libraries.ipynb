# %% [markdown]
# # Install last week's required packages plus those for this week
#
# Installing all packages in one line gives the highest chance of them all being compatible.
#
#     conda install -c conda-forge xarray cartopy geopandas netcdf4 h5py gdal fiona
#
# Type ```y``` to say yes to everything.
#
# If the cell below runs without errors, you should be good to go:

# %%
import cartopy
import xarray
import netCDF4
import geopandas
import gdal
import fiona
import shapely
import h5py

# %% [markdown]
# **Import a shapefile (```.shp``` extension)**
#
# This is in the ```materials/data/shapefiles/``` directory of the GitHub respository.  If you don't want to download these data, you can try your own .shp file.
#
# **NOTE:**  A well-documented shapefile should always have the coordinate reference system (crs) contained within it, so that the user can understand how to project it onto a map.  Access this using the ```.crs``` object:

# %%
ca_ecoregions_gdf = geopandas.read_file('../data/shapefiles/ca_eco_l3/ca_eco_l3.shp')
ca_ecoregions_gdf = geopandas.read_file('../data/shapefiles/ca_eco_l3/ca_eco_l3.shp')
print(ca_ecoregions_gdf.crs)
# Out:
# {'init': 'epsg:5070'}

# %% [markdown]
# **You may need to run this twice to get a plot:**

# %%
ca_ecoregions_gdf.plot()
